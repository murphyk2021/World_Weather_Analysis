# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#import Requests library
import requests as req
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Create an empty list to hold the weather data.
city_data = []


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descript=city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_descript})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | padang
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | tazovskiy
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | yeniseysk
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | somerset west
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | dingle
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | naze
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | karratha
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | manado
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | evensk
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | cabedelo
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | comodoro rivadavia
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | lufilufi
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | mount isa
# Processing Record 38 of Set 1 | buchanan
# Processing Record 39 of Set 1 | ciudad bolivar
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | boysun
# Processing Record 44 of Set 1 | carballo
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | eureka
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | bubaque
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | oksovskiy
# Processing Record 2 of Set 2 | beloha
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | mandiana
# Processing Record 6 of Set 2 | tura
# Processing Record 7 of Set 2 | bilibino
# Processing Record 8 of Set 2 | shelburne
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | pemberton
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | gondanglegi
# Processing Record 14 of Set 2 | hamilton
# Processing Record 15 of Set 2 | kollam
# Processing Record 16 of Set 2 | itarema
# Processing Record 17 of Set 2 | asau
# Processing Record 18 of Set 2 | hasaki
# Processing Record 19 of Set 2 | wainwright
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | nome
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | barranca
# Processing Record 24 of Set 2 | kholtoson
# Processing Record 25 of Set 2 | adrar
# Processing Record 26 of Set 2 | tashla
# Processing Record 27 of Set 2 | powell river
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | svetlaya
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | muzhi
# Processing Record 37 of Set 2 | reconquista
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | santona
# Processing Record 40 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 2 | quzhou
# Processing Record 42 of Set 2 | santiago
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | marawi
# Processing Record 49 of Set 2 | sitka
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | kaoma
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | sistranda
# Processing Record 5 of Set 3 | san quintin
# Processing Record 6 of Set 3 | maarianhamina
# Processing Record 7 of Set 3 | kpalime
# Processing Record 8 of Set 3 | pringsewu
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | matay
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | nova vicosa
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | rikitea
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 3 | sovetskiy
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | acapulco
# Processing Record 22 of Set 3 | labrea
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | pativilca
# Processing Record 25 of Set 3 | namatanai
# Processing Record 26 of Set 3 | arkhipo-osipovka
# Processing Record 27 of Set 3 | santa lucia
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | sinnamary
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | ola
# Processing Record 42 of Set 3 | port moresby
# Processing Record 43 of Set 3 | ust-nera
# Processing Record 44 of Set 3 | port-gentil
# Processing Record 45 of Set 3 | hambantota
# Processing Record 46 of Set 3 | haileybury
# Processing Record 47 of Set 3 | salina
# Processing Record 48 of Set 3 | maragogi
# Processing Record 49 of Set 3 | lyubymivka
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | marietta
# Processing Record 2 of Set 4 | tafresh
# Processing Record 3 of Set 4 | atuona
# Processing Record 4 of Set 4 | jalu
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | kuching
# Processing Record 8 of Set 4 | mareeba
# Processing Record 9 of Set 4 | qaqortoq
# Processing Record 10 of Set 4 | belyy yar
# Processing Record 11 of Set 4 | westport
# Processing Record 12 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | bontang
# Processing Record 15 of Set 4 | pokhara
# Processing Record 16 of Set 4 | la rioja
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | sechura
# Processing Record 19 of Set 4 | kiruna
# Processing Record 20 of Set 4 | seddon
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | jacareacanga
# Processing Record 25 of Set 4 | marck
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | hofn
# Processing Record 28 of Set 4 | beyneu
# Processing Record 29 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | juneau
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | champerico
# Processing Record 33 of Set 4 | mahon
# Processing Record 34 of Set 4 | ixtapa
# Processing Record 35 of Set 4 | faya
# Processing Record 36 of Set 4 | bahia blanca
# Processing Record 37 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | mbanza-ngungu
# Processing Record 39 of Set 4 | menongue
# Processing Record 40 of Set 4 | praia
# Processing Record 41 of Set 4 | yarke pole
# Processing Record 42 of Set 4 | chapulhuacan
# Processing Record 43 of Set 4 | tevaitoa
# Processing Record 44 of Set 4 | tongliao
# Processing Record 45 of Set 4 | baruun-urt
# Processing Record 46 of Set 4 | lakselv
# Processing Record 47 of Set 4 | fukue
# Processing Record 48 of Set 4 | harper
# Processing Record 49 of Set 4 | moscow
# Processing Record 50 of Set 4 | maltahohe
# Processing Record 1 of Set 5 | maceio
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | nalut
# Processing Record 4 of Set 5 | port hawkesbury
# Processing Record 5 of Set 5 | kudat
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | quatre cocos
# Processing Record 8 of Set 5 | timra
# Processing Record 9 of Set 5 | port hardy
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | kodinsk
# Processing Record 12 of Set 5 | berlevag
# Processing Record 13 of Set 5 | batticaloa
# Processing Record 14 of Set 5 | grootfontein
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | kamenka
# Processing Record 17 of Set 5 | athabasca
# Processing Record 18 of Set 5 | orangeburg
# Processing Record 19 of Set 5 | smithers
# Processing Record 20 of Set 5 | rantauprapat
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | dongsheng
# Processing Record 23 of Set 5 | scarborough
# Processing Record 24 of Set 5 | chippewa falls
# Processing Record 25 of Set 5 | lumeje
# Processing Record 26 of Set 5 | novopokrovka
# Processing Record 27 of Set 5 | muros
# Processing Record 28 of Set 5 | sturgis
# Processing Record 29 of Set 5 | yazman
# Processing Record 30 of Set 5 | zaria
# Processing Record 31 of Set 5 | jasper
# Processing Record 32 of Set 5 | yashalta
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | hollola
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | whyalla
# Processing Record 38 of Set 5 | hualmay
# Processing Record 39 of Set 5 | georgetown
# Processing Record 40 of Set 5 | tual
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | pevek
# Processing Record 43 of Set 5 | clyde river
# Processing Record 44 of Set 5 | port augusta
# Processing Record 45 of Set 5 | cranbrook
# Processing Record 46 of Set 5 | seia
# Processing Record 47 of Set 5 | goaigoaza
# City not found. Skipping...
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 50 of Set 5 | makokou
# Processing Record 1 of Set 6 | popondetta
# Processing Record 2 of Set 6 | susangerd
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | mayo
# Processing Record 6 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | anshun
# Processing Record 8 of Set 6 | gimli
# Processing Record 9 of Set 6 | znamenskoye
# Processing Record 10 of Set 6 | ankazoabo
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | soyo
# Processing Record 13 of Set 6 | sharjah
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 6 | horsham
# Processing Record 17 of Set 6 | nyahururu
# Processing Record 18 of Set 6 | yar-sale
# Processing Record 19 of Set 6 | kapaa
# Processing Record 20 of Set 6 | badulla
# Processing Record 21 of Set 6 | trairi
# Processing Record 22 of Set 6 | sitamau
# Processing Record 23 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 6 | broome
# Processing Record 25 of Set 6 | charters towers
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | yellowknife
# Processing Record 28 of Set 6 | rock hill
# Processing Record 29 of Set 6 | terrace
# Processing Record 30 of Set 6 | mar del plata
# Processing Record 31 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 32 of Set 6 | fuling
# Processing Record 33 of Set 6 | genhe
# Processing Record 34 of Set 6 | tucurui
# Processing Record 35 of Set 6 | college
# Processing Record 36 of Set 6 | dalby
# Processing Record 37 of Set 6 | port hedland
# Processing Record 38 of Set 6 | ambilobe
# Processing Record 39 of Set 6 | lebu
# Processing Record 40 of Set 6 | bosaso
# Processing Record 41 of Set 6 | nuuk
# Processing Record 42 of Set 6 | akonolinga
# Processing Record 43 of Set 6 | svetlyy
# Processing Record 44 of Set 6 | boguchany
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | leningradskiy
# Processing Record 47 of Set 6 | jumla
# Processing Record 48 of Set 6 | takoradi
# Processing Record 49 of Set 6 | alyangula
# Processing Record 50 of Set 6 | jinchang
# Processing Record 1 of Set 7 | bukachacha
# Processing Record 2 of Set 7 | glubokoe
# City not found. Skipping...
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 7 | nizhniy kuranakh
# Processing Record 6 of Set 7 | rovaniemi
# Processing Record 7 of Set 7 | fort nelson
# Processing Record 8 of Set 7 | terrace bay
# Processing Record 9 of Set 7 | altamont
# Processing Record 10 of Set 7 | tarko-sale
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | cedar city
# Processing Record 13 of Set 7 | ngunguru
# Processing Record 14 of Set 7 | kaukauna
# Processing Record 15 of Set 7 | casablanca
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | nouadhibou
# Processing Record 18 of Set 7 | iqaluit
# Processing Record 19 of Set 7 | lorengau
# Processing Record 20 of Set 7 | roela
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | natal
# Processing Record 24 of Set 7 | uribia
# Processing Record 25 of Set 7 | shubarkuduk
# Processing Record 26 of Set 7 | kununurra
# Processing Record 27 of Set 7 | itoman
# Processing Record 28 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 7 | sawakin
# Processing Record 30 of Set 7 | laa
# Processing Record 31 of Set 7 | kalmunai
# Processing Record 32 of Set 7 | honningsvag
# Processing Record 33 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 7 | dumbravita
# Processing Record 35 of Set 7 | bowen
# Processing Record 36 of Set 7 | ponta delgada
# Processing Record 37 of Set 7 | huarmey
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 40 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 7 | banda aceh
# Processing Record 42 of Set 7 | severnyy-kospashskiy
# Processing Record 43 of Set 7 | rundu
# Processing Record 44 of Set 7 | illela
# Processing Record 45 of Set 7 | crestview
# Processing Record 46 of Set 7 | tanout
# Processing Record 47 of Set 7 | martinsville
# Processing Record 48 of Set 7 | surazh
# Processing Record 49 of Set 7 | nanortalik
# Processing Record 50 of Set 7 | anadyr
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | tabuk
# Processing Record 3 of Set 8 | yantal
# Processing Record 4 of Set 8 | kruisfontein
# Processing Record 5 of Set 8 | yushu
# Processing Record 6 of Set 8 | mayskiy
# Processing Record 7 of Set 8 | valle de allende
# Processing Record 8 of Set 8 | zhuhai
# Processing Record 9 of Set 8 | rawson
# Processing Record 10 of Set 8 | kaitangata
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | bull savanna
# Processing Record 13 of Set 8 | panguna
# Processing Record 14 of Set 8 | boende
# Processing Record 15 of Set 8 | kantunilkin
# Processing Record 16 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 8 | okakarara
# Processing Record 19 of Set 8 | kyshtovka
# Processing Record 20 of Set 8 | emba
# Processing Record 21 of Set 8 | ciudad guayana
# Processing Record 22 of Set 8 | bobcaygeon
# Processing Record 23 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | lagoa
# Processing Record 25 of Set 8 | ginir
# Processing Record 26 of Set 8 | kihei
# Processing Record 27 of Set 8 | esfarayen
# Processing Record 28 of Set 8 | chernyshevskiy
# Processing Record 29 of Set 8 | mattru
# Processing Record 30 of Set 8 | guarapari
# Processing Record 31 of Set 8 | vizinga
# Processing Record 32 of Set 8 | guerrero negro
# Processing Record 33 of Set 8 | porbandar
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | hovd
# Processing Record 36 of Set 8 | pangoa
# Processing Record 37 of Set 8 | kortkeros
# Processing Record 38 of Set 8 | kloulklubed
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | bambous virieux
# Processing Record 41 of Set 8 | ust-barguzin
# Processing Record 42 of Set 8 | mopipi
# Processing Record 43 of Set 8 | tucumcari
# Processing Record 44 of Set 8 | saint-francois
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | turayf
# Processing Record 47 of Set 8 | praia da vitoria
# Processing Record 48 of Set 8 | waingapu
# Processing Record 49 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 8 | ankazobe
# Processing Record 1 of Set 9 | sept-iles
# Processing Record 2 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 9 | vao
# Processing Record 4 of Set 9 | melo
# Processing Record 5 of Set 9 | lock haven
# Processing Record 6 of Set 9 | rieti
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | almeirim
# Processing Record 9 of Set 9 | kayes
# Processing Record 10 of Set 9 | cayenne
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | kolondieba
# Processing Record 13 of Set 9 | irtyshskiy
# Processing Record 14 of Set 9 | jinka
# Processing Record 15 of Set 9 | cotonou
# Processing Record 16 of Set 9 | strezhevoy
# Processing Record 17 of Set 9 | porto velho
# Processing Record 18 of Set 9 | camacha
# Processing Record 19 of Set 9 | kahului
# Processing Record 20 of Set 9 | garissa
# Processing Record 21 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 22 of Set 9 | lasa
# Processing Record 23 of Set 9 | kailua
# Processing Record 24 of Set 9 | pangai
# Processing Record 25 of Set 9 | marquette
# Processing Record 26 of Set 9 | talcahuano
# Processing Record 27 of Set 9 | norman wells
# Processing Record 28 of Set 9 | tessalit
# Processing Record 29 of Set 9 | bolshoy lug
# Processing Record 30 of Set 9 | shizunai
# Processing Record 31 of Set 9 | mitsamiouli
# Processing Record 32 of Set 9 | lansing
# Processing Record 33 of Set 9 | benguela
# Processing Record 34 of Set 9 | sangar
# Processing Record 35 of Set 9 | freetown
# Processing Record 36 of Set 9 | tomatlan
# Processing Record 37 of Set 9 | along
# Processing Record 38 of Set 9 | jabinyanah
# Processing Record 39 of Set 9 | cap-aux-meules
# Processing Record 40 of Set 9 | mount vernon
# Processing Record 41 of Set 9 | faanui
# Processing Record 42 of Set 9 | palmer
# Processing Record 43 of Set 9 | dharchula
# Processing Record 44 of Set 9 | birjand
# Processing Record 45 of Set 9 | muisne
# Processing Record 46 of Set 9 | malartic
# Processing Record 47 of Set 9 | denpasar
# Processing Record 48 of Set 9 | zhigalovo
# Processing Record 49 of Set 9 | patur
# Processing Record 50 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | ginosa
# Processing Record 3 of Set 10 | senneterre
# Processing Record 4 of Set 10 | ballina
# Processing Record 5 of Set 10 | souillac
# Processing Record 6 of Set 10 | kargasok
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | codrington
# Processing Record 9 of Set 10 | zabol
# Processing Record 10 of Set 10 | tiarei
# Processing Record 11 of Set 10 | leshukonskoye
# Processing Record 12 of Set 10 | conceicao do araguaia
# Processing Record 13 of Set 10 | portland
# Processing Record 14 of Set 10 | golkoy
# Processing Record 15 of Set 10 | vila
# Processing Record 16 of Set 10 | laguna
# Processing Record 17 of Set 10 | kiunga
# Processing Record 18 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 10 | lalibela
# Processing Record 20 of Set 10 | magnolia
# Processing Record 21 of Set 10 | salinas
# Processing Record 22 of Set 10 | georgiyevka
# Processing Record 23 of Set 10 | esperance
# Processing Record 24 of Set 10 | taoudenni
# Processing Record 25 of Set 10 | wageningen
# Processing Record 26 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 10 | bengkulu
# Processing Record 28 of Set 10 | nemuro
# Processing Record 29 of Set 10 | isiro
# Processing Record 30 of Set 10 | brae
# Processing Record 31 of Set 10 | visby
# Processing Record 32 of Set 10 | hami
# Processing Record 33 of Set 10 | mugumu
# Processing Record 34 of Set 10 | sal rei
# Processing Record 35 of Set 10 | redlands
# Processing Record 36 of Set 10 | yanam
# Processing Record 37 of Set 10 | talnakh
# Processing Record 38 of Set 10 | mombetsu
# Processing Record 39 of Set 10 | iberia
# Processing Record 40 of Set 10 | balikpapan
# Processing Record 41 of Set 10 | dondo
# Processing Record 42 of Set 10 | bud
# Processing Record 43 of Set 10 | chicama
# Processing Record 44 of Set 10 | rio cuarto
# Processing Record 45 of Set 10 | ngaoundere
# Processing Record 46 of Set 10 | san patricio
# Processing Record 47 of Set 10 | uzunkopru
# City not found. Skipping...
# Processing Record 48 of Set 10 | samarai
# Processing Record 49 of Set 10 | lopsmarka
# Processing Record 50 of Set 10 | zakopane
# Processing Record 1 of Set 11 | grao mogol
# Processing Record 2 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | pasighat
# Processing Record 4 of Set 11 | riviere-au-renard
# Processing Record 5 of Set 11 | soe
# Processing Record 6 of Set 11 | khandyga
# Processing Record 7 of Set 11 | desaguadero
# Processing Record 8 of Set 11 | agva
# City not found. Skipping...
# Processing Record 9 of Set 11 | plouzane
# Processing Record 10 of Set 11 | havelock
# Processing Record 11 of Set 11 | atasu
# Processing Record 12 of Set 11 | mandera
# Processing Record 13 of Set 11 | suntar
# Processing Record 14 of Set 11 | rangia
# Processing Record 15 of Set 11 | fare
# Processing Record 16 of Set 11 | tarboro
# Processing Record 17 of Set 11 | roma
# Processing Record 18 of Set 11 | los llanos de aridane
# Processing Record 19 of Set 11 | lagos
# Processing Record 20 of Set 11 | voh
# Processing Record 21 of Set 11 | kundiawa
# Processing Record 22 of Set 11 | cockburn town
# Processing Record 23 of Set 11 | hailar
# Processing Record 24 of Set 11 | salalah
# Processing Record 25 of Set 11 | egvekinot
# Processing Record 26 of Set 11 | eydhafushi
# Processing Record 27 of Set 11 | orange
# Processing Record 28 of Set 11 | vysokogornyy
# Processing Record 29 of Set 11 | lebane
# Processing Record 30 of Set 11 | fairview
# Processing Record 31 of Set 11 | darnah
# Processing Record 32 of Set 11 | jibuti
# Processing Record 33 of Set 11 | parabel
# Processing Record 34 of Set 11 | aklavik
# Processing Record 35 of Set 11 | capreol
# Processing Record 36 of Set 11 | mamallapuram
# Processing Record 37 of Set 11 | lavrentiya
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | urengoy
# Processing Record 40 of Set 11 | bulaevo
# Processing Record 41 of Set 11 | tuim
# Processing Record 42 of Set 11 | caibarien
# Processing Record 43 of Set 11 | loa janan
# Processing Record 44 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | yatou
# Processing Record 46 of Set 11 | praxedis guerrero
# Processing Record 47 of Set 11 | north platte
# Processing Record 48 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 49 of Set 11 | shimoda
# Processing Record 50 of Set 11 | the valley
# Processing Record 1 of Set 12 | ndele
# Processing Record 2 of Set 12 | stromness
# Processing Record 3 of Set 12 | yichang
# Processing Record 4 of Set 12 | buarcos
# Processing Record 5 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 12 | lewiston
# Processing Record 7 of Set 12 | abong mbang
# Processing Record 8 of Set 12 | silyanah
# City not found. Skipping...
# Processing Record 9 of Set 12 | normandin
# Processing Record 10 of Set 12 | basco
# Processing Record 11 of Set 12 | diamantino
# Processing Record 12 of Set 12 | huilong
# Processing Record 13 of Set 12 | celestun
# Processing Record 14 of Set 12 | vestmannaeyjar
# Processing Record 15 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 12 | baijiantan
# Processing Record 17 of Set 12 | lompoc
# Processing Record 18 of Set 12 | bandarbeyla
# Processing Record 19 of Set 12 | dali
# Processing Record 20 of Set 12 | yulara
# Processing Record 21 of Set 12 | brown deer
# Processing Record 22 of Set 12 | baracoa
# Processing Record 23 of Set 12 | staffanstorp
# Processing Record 24 of Set 12 | sur
# Processing Record 25 of Set 12 | paderborn
# Processing Record 26 of Set 12 | tilichiki
# Processing Record 27 of Set 12 | anahuac
# Processing Record 28 of Set 12 | tuatapere
# Processing Record 29 of Set 12 | kenora
# Processing Record 30 of Set 12 | salinopolis
# Processing Record 31 of Set 12 | vasudevanallur
# Processing Record 32 of Set 12 | bulawayo
# Processing Record 33 of Set 12 | malanje
# Processing Record 34 of Set 12 | necochea
# Processing Record 35 of Set 12 | santa maria
# Processing Record 36 of Set 12 | ketchikan
# Processing Record 37 of Set 12 | belmonte
# Processing Record 38 of Set 12 | te anau
# Processing Record 39 of Set 12 | lae
# Processing Record 40 of Set 12 | axim
# Processing Record 41 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 12 | kataysk
# Processing Record 43 of Set 12 | kwinana
# Processing Record 44 of Set 12 | lazaro cardenas
# Processing Record 45 of Set 12 | pinawa
# Processing Record 46 of Set 12 | mackay
# Processing Record 47 of Set 12 | severodvinsk
# Processing Record 48 of Set 12 | aykhal
# Processing Record 49 of Set 12 | great yarmouth
# Processing Record 50 of Set 12 | nyurba
# Processing Record 1 of Set 13 | pesqueria
# Processing Record 2 of Set 13 | neiafu
# Processing Record 3 of Set 13 | morag
# Processing Record 4 of Set 13 | ulagan
# Processing Record 5 of Set 13 | sabha
# Processing Record 6 of Set 13 | saint-pierre
# Processing Record 7 of Set 13 | port lincoln
# Processing Record 8 of Set 13 | hendek
# Processing Record 9 of Set 13 | matara
# Processing Record 10 of Set 13 | viedma
# Processing Record 11 of Set 13 | magadi
# Processing Record 12 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 13 | vanimo
# Processing Record 14 of Set 13 | saint-denis
# Processing Record 15 of Set 13 | burica
# City not found. Skipping...
# Processing Record 16 of Set 13 | manakara
# Processing Record 17 of Set 13 | manokwari
# Processing Record 18 of Set 13 | miraflores
# Processing Record 19 of Set 13 | aripuana
# Processing Record 20 of Set 13 | moranbah
# Processing Record 21 of Set 13 | havre
# Processing Record 22 of Set 13 | batemans bay
# Processing Record 23 of Set 13 | gubkinskiy
# Processing Record 24 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 13 | hattiesburg
# Processing Record 26 of Set 13 | dunga bunga
# Processing Record 27 of Set 13 | chuguyevka
# Processing Record 28 of Set 13 | williamsport
# Processing Record 29 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 30 of Set 13 | suksun
# Processing Record 31 of Set 13 | council bluffs
# Processing Record 32 of Set 13 | nara
# Processing Record 33 of Set 13 | la reforma
# Processing Record 34 of Set 13 | hukuntsi
# Processing Record 35 of Set 13 | maryborough
# Processing Record 36 of Set 13 | itambacuri
# Processing Record 37 of Set 13 | biloela
# Processing Record 38 of Set 13 | mama
# Processing Record 39 of Set 13 | dubno
# Processing Record 40 of Set 13 | gorin
# Processing Record 41 of Set 13 | coahuayana
# Processing Record 42 of Set 13 | coquimbo
# Processing Record 43 of Set 13 | porto walter
# Processing Record 44 of Set 13 | halifax
# Processing Record 45 of Set 13 | yunyang
# Processing Record 46 of Set 13 | shingu
# Processing Record 47 of Set 13 | loreto
# Processing Record 48 of Set 13 | kieta
# Processing Record 49 of Set 13 | fairbanks
# Processing Record 50 of Set 13 | muroto
# Processing Record 1 of Set 14 | tukrah
# Processing Record 2 of Set 14 | angoche
# Processing Record 3 of Set 14 | imbituba
# Processing Record 4 of Set 14 | kenai
# Processing Record 5 of Set 14 | zernograd
# Processing Record 6 of Set 14 | skjervoy
# Processing Record 7 of Set 14 | moose factory
# Processing Record 8 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 14 | bolobo
# Processing Record 11 of Set 14 | pleshanovo
# Processing Record 12 of Set 14 | nabire
# Processing Record 13 of Set 14 | singaraja
# Processing Record 14 of Set 14 | wilmington
# Processing Record 15 of Set 14 | birao
# Processing Record 16 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 14 | biabou
# Processing Record 18 of Set 14 | les cayes
# Processing Record 19 of Set 14 | scottsbluff
# Processing Record 20 of Set 14 | vyritsa
# Processing Record 21 of Set 14 | a
# City not found. Skipping...
# Processing Record 22 of Set 14 | ilhabela
# Processing Record 23 of Set 14 | mana
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | noumea
# Processing Record 26 of Set 14 | nyrob
# Processing Record 27 of Set 14 | todos santos
# Processing Record 28 of Set 14 | proletarskiy
# Processing Record 29 of Set 14 | hongjiang
# Processing Record 30 of Set 14 | jiazi
# Processing Record 31 of Set 14 | inhambane
# Processing Record 32 of Set 14 | bondoukou
# Processing Record 33 of Set 14 | charlottesville
# Processing Record 34 of Set 14 | meadow lake
# Processing Record 35 of Set 14 | virginia beach
# Processing Record 36 of Set 14 | banjar
# Processing Record 37 of Set 14 | coleraine
# Processing Record 38 of Set 14 | nelson bay
# Processing Record 39 of Set 14 | progreso
# Processing Record 40 of Set 14 | sao felix do xingu
# Processing Record 41 of Set 14 | sao joao da barra
# Processing Record 42 of Set 14 | meulaboh
# Processing Record 43 of Set 14 | gouyave
# Processing Record 44 of Set 14 | slimnic
# Processing Record 45 of Set 14 | dudinka
# Processing Record 46 of Set 14 | roald
# Processing Record 47 of Set 14 | cuamba
# Processing Record 48 of Set 14 | awbari
# Processing Record 49 of Set 14 | mogadishu
# Processing Record 50 of Set 14 | tanabe
# Processing Record 1 of Set 15 | galle
# Processing Record 2 of Set 15 | bhanpura
# Processing Record 3 of Set 15 | sikeston
# Processing Record 4 of Set 15 | santa cruz
# Processing Record 5 of Set 15 | monte alegre de sergipe
# Processing Record 6 of Set 15 | wuhu
# Processing Record 7 of Set 15 | rancho palos verdes
# Processing Record 8 of Set 15 | yazd
# Processing Record 9 of Set 15 | mbandaka
# Processing Record 10 of Set 15 | sobolevo
# Processing Record 11 of Set 15 | ukiah
# Processing Record 12 of Set 15 | chiredzi
# Processing Record 13 of Set 15 | brawley
# Processing Record 14 of Set 15 | kavaratti
# Processing Record 15 of Set 15 | turukhansk
# Processing Record 16 of Set 15 | suluq
# Processing Record 17 of Set 15 | anau
# Processing Record 18 of Set 15 | san buenaventura
# Processing Record 19 of Set 15 | high rock
# Processing Record 20 of Set 15 | kitimat
# Processing Record 21 of Set 15 | muhos
# Processing Record 22 of Set 15 | manaus
# Processing Record 23 of Set 15 | san isidro
# Processing Record 24 of Set 15 | bozhou
# Processing Record 25 of Set 15 | panorama
# Processing Record 26 of Set 15 | bloomsburg
# Processing Record 27 of Set 15 | qiongshan
# Processing Record 28 of Set 15 | panacan
# Processing Record 29 of Set 15 | houlung
# City not found. Skipping...
# Processing Record 30 of Set 15 | ust-omchug
# Processing Record 31 of Set 15 | ulaangom
# Processing Record 32 of Set 15 | waipawa
# Processing Record 33 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 34 of Set 15 | ust-maya
# Processing Record 35 of Set 15 | visnes
# Processing Record 36 of Set 15 | vuktyl
# Processing Record 37 of Set 15 | nishihara
# Processing Record 38 of Set 15 | la asuncion
# Processing Record 39 of Set 15 | adeje
# Processing Record 40 of Set 15 | gat
# Processing Record 41 of Set 15 | yarim
# Processing Record 42 of Set 15 | udachnyy
# Processing Record 43 of Set 15 | verkhnyaya inta
# Processing Record 44 of Set 15 | svetlogorsk
# Processing Record 45 of Set 15 | linfen
# Processing Record 46 of Set 15 | tbilisskaya
# Processing Record 47 of Set 15 | north bend
# Processing Record 48 of Set 15 | kaltasy
# Processing Record 49 of Set 15 | imeni telmana
# City not found. Skipping...
# Processing Record 50 of Set 15 | mortka
# Processing Record 1 of Set 16 | burgeo
# Processing Record 2 of Set 16 | singkang
# Processing Record 3 of Set 16 | port-de-bouc
# Processing Record 4 of Set 16 | craig
# Processing Record 5 of Set 16 | ilo
# Processing Record 6 of Set 16 | surt
# Processing Record 7 of Set 16 | duartina
# Processing Record 8 of Set 16 | fillan
# Processing Record 9 of Set 16 | teya
# Processing Record 10 of Set 16 | sokolskoye
# Processing Record 11 of Set 16 | monduli
# Processing Record 12 of Set 16 | pangkalanbuun
# Processing Record 13 of Set 16 | aasiaat
# Processing Record 14 of Set 16 | camabatela
# Processing Record 15 of Set 16 | zakharovo
# Processing Record 16 of Set 16 | nassjo
# Processing Record 17 of Set 16 | bongandanga
# Processing Record 18 of Set 16 | vung tau
# Processing Record 19 of Set 16 | bonito
# Processing Record 20 of Set 16 | mendi
# Processing Record 21 of Set 16 | cheyenne
# Processing Record 22 of Set 16 | dortyol
# Processing Record 23 of Set 16 | buritizeiro
# Processing Record 24 of Set 16 | tadine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bethel      US  41.3712  -73.4140     90.45        46           1
# 1      Ushuaia      AR -54.8000  -68.3000     44.26        57          40
# 2       Avarua      CK -21.2078 -159.7750     75.25        60          75
# 3    Cape Town      ZA -33.9258   18.4232     72.01        27           0
# 4        Tiksi      RU  71.6872  128.8694     43.83        64         100
# 5  Provideniya      RU  64.3833 -173.3000     44.71        61          75
# 6   Nikolskoye      RU  59.7035   30.7861     60.69        83          70
# 7       Padang      ID  -0.9492  100.3543     75.60        78          78
# 8    Tazovskiy      RU  67.4667   78.7000     32.09        86          94
# 9         Hilo      US  19.7297 -155.0900     80.33        72          90
#
#    Wind Speed Current Description
# 0        9.22           clear sky
# 1       12.66    scattered clouds
# 2        5.75       broken clouds
# 3       13.22           clear sky
# 4        1.54     overcast clouds
# 5        6.71       broken clouds
# 6        3.65       broken clouds
# 7        3.83       broken clouds
# 8        9.01     overcast clouds
# 9       13.80          light rain

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
