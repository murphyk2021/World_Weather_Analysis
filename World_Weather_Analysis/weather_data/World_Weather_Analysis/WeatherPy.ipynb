# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#import Requests library
import requests as req
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 591

# %%
# Create an empty list to hold the weather data.
city_data = []


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | magadi
# Processing Record 2 of Set 1 | hare bay
# Processing Record 3 of Set 1 | villarrica
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | kalmunai
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | emerald
# Processing Record 13 of Set 1 | guayaramerin
# Processing Record 14 of Set 1 | berlevag
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | sawtell
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | wanning
# Processing Record 22 of Set 1 | wajir
# Processing Record 23 of Set 1 | sawai madhopur
# Processing Record 24 of Set 1 | bilma
# Processing Record 25 of Set 1 | dalvik
# Processing Record 26 of Set 1 | egvekinot
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | westport
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | solnechnyy
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | gat
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | krasnorechenskiy
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | namatanai
# Processing Record 41 of Set 1 | ukiah
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | muscat
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | henties bay
# Processing Record 49 of Set 1 | port blair
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | balkanabat
# Processing Record 3 of Set 2 | klyuchi
# Processing Record 4 of Set 2 | murdochville
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | vardo
# Processing Record 7 of Set 2 | chapais
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | cedar city
# Processing Record 12 of Set 2 | faro
# Processing Record 13 of Set 2 | rio grande
# Processing Record 14 of Set 2 | bonoua
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | ranong
# Processing Record 17 of Set 2 | palu
# Processing Record 18 of Set 2 | paita
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | sulphur
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | nokia
# Processing Record 23 of Set 2 | tuy hoa
# Processing Record 24 of Set 2 | bonthe
# Processing Record 25 of Set 2 | grevesmuhlen
# Processing Record 26 of Set 2 | mabaruma
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | koslan
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | ilhabela
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | catio
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | goderich
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | bandar-e lengeh
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | jiuquan
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | menongue
# Processing Record 43 of Set 2 | mazeikiai
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | hearst
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | cururupu
# Processing Record 3 of Set 3 | palombara sabina
# Processing Record 4 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 3 | biak
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | fujin
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | leshukonskoye
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | batagay-alyta
# Processing Record 15 of Set 3 | olafsvik
# Processing Record 16 of Set 3 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | riyadh
# Processing Record 20 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 3 | dongsheng
# Processing Record 22 of Set 3 | grand-santi
# Processing Record 23 of Set 3 | havre
# Processing Record 24 of Set 3 | launceston
# Processing Record 25 of Set 3 | colquechaca
# Processing Record 26 of Set 3 | dubbo
# Processing Record 27 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | pathein
# Processing Record 31 of Set 3 | lamar
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | waingapu
# Processing Record 35 of Set 3 | mehamn
# Processing Record 36 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | lebanon
# Processing Record 40 of Set 3 | hami
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | kincardine
# Processing Record 43 of Set 3 | warrnambool
# Processing Record 44 of Set 3 | sabzevar
# Processing Record 45 of Set 3 | dukat
# Processing Record 46 of Set 3 | tiarei
# Processing Record 47 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 3 | tsarychanka
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | camapua
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | nan
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | smrzovka
# Processing Record 10 of Set 4 | chalmette
# Processing Record 11 of Set 4 | flin flon
# Processing Record 12 of Set 4 | chuguyevka
# Processing Record 13 of Set 4 | tateyama
# Processing Record 14 of Set 4 | ibra
# Processing Record 15 of Set 4 | cap-aux-meules
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | nanning
# Processing Record 18 of Set 4 | san isidro
# Processing Record 19 of Set 4 | lakes entrance
# Processing Record 20 of Set 4 | calvinia
# Processing Record 21 of Set 4 | matamba
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 4 | pinheiro machado
# Processing Record 25 of Set 4 | kharan
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | cayenne
# Processing Record 28 of Set 4 | taitung
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | hangu
# Processing Record 32 of Set 4 | makakilo city
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | umm kaddadah
# Processing Record 36 of Set 4 | tankhoy
# Processing Record 37 of Set 4 | terney
# Processing Record 38 of Set 4 | carbonia
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | tahta
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | katherine
# Processing Record 43 of Set 4 | dehloran
# Processing Record 44 of Set 4 | yulara
# Processing Record 45 of Set 4 | mumford
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | lesnoye
# Processing Record 49 of Set 4 | college
# Processing Record 50 of Set 4 | hermanus
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | predivinsk
# Processing Record 4 of Set 5 | waddan
# Processing Record 5 of Set 5 | opuwo
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 5 | chokurdakh
# Processing Record 10 of Set 5 | paamiut
# Processing Record 11 of Set 5 | vanimo
# Processing Record 12 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 5 | chany
# Processing Record 14 of Set 5 | save
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | sibolga
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | batangafo
# Processing Record 19 of Set 5 | madimba
# Processing Record 20 of Set 5 | shilka
# Processing Record 21 of Set 5 | ambalavao
# Processing Record 22 of Set 5 | zunyi
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | shitanjing
# Processing Record 28 of Set 5 | redcar
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | aquiraz
# Processing Record 31 of Set 5 | oranjemund
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | bereda
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | medina
# Processing Record 36 of Set 5 | almaznyy
# Processing Record 37 of Set 5 | inta
# Processing Record 38 of Set 5 | bismil
# Processing Record 39 of Set 5 | lavrentiya
# Processing Record 40 of Set 5 | lanivtsi
# Processing Record 41 of Set 5 | khatanga
# Processing Record 42 of Set 5 | suwalki
# Processing Record 43 of Set 5 | evensk
# Processing Record 44 of Set 5 | beringovskiy
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | roma
# Processing Record 47 of Set 5 | sarab
# Processing Record 48 of Set 5 | baghdad
# Processing Record 49 of Set 5 | gawler
# Processing Record 50 of Set 5 | gigmoto
# Processing Record 1 of Set 6 | bairiki
# Processing Record 2 of Set 6 | shache
# Processing Record 3 of Set 6 | adrar
# Processing Record 4 of Set 6 | fukue
# Processing Record 5 of Set 6 | lasa
# Processing Record 6 of Set 6 | yaring
# Processing Record 7 of Set 6 | kalat
# Processing Record 8 of Set 6 | tarakan
# Processing Record 9 of Set 6 | aberdeen
# Processing Record 10 of Set 6 | west wendover
# Processing Record 11 of Set 6 | hirado
# Processing Record 12 of Set 6 | hovd
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | maues
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | guatire
# Processing Record 17 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 18 of Set 6 | monywa
# Processing Record 19 of Set 6 | vila do maio
# Processing Record 20 of Set 6 | macusani
# Processing Record 21 of Set 6 | zheleznodorozhnyy
# Processing Record 22 of Set 6 | tabou
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | mozarlandia
# Processing Record 25 of Set 6 | klyuchevskiy
# Processing Record 26 of Set 6 | chifeng
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | anadyr
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | graaff-reinet
# Processing Record 31 of Set 6 | luang prabang
# Processing Record 32 of Set 6 | san policarpo
# Processing Record 33 of Set 6 | san marcos
# Processing Record 34 of Set 6 | turbat
# Processing Record 35 of Set 6 | nuuk
# Processing Record 36 of Set 6 | rio gallegos
# Processing Record 37 of Set 6 | zhezkazgan
# Processing Record 38 of Set 6 | tanout
# Processing Record 39 of Set 6 | lintangan
# Processing Record 40 of Set 6 | sulingen
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | agirish
# Processing Record 43 of Set 6 | kalulushi
# Processing Record 44 of Set 6 | lar
# Processing Record 45 of Set 6 | mayo
# Processing Record 46 of Set 6 | necochea
# Processing Record 47 of Set 6 | ribeira grande
# Processing Record 48 of Set 6 | nhulunbuy
# Processing Record 49 of Set 6 | manuk mangkaw
# Processing Record 50 of Set 6 | pacasmayo
# Processing Record 1 of Set 7 | homer
# Processing Record 2 of Set 7 | portel
# Processing Record 3 of Set 7 | gurlan
# Processing Record 4 of Set 7 | houma
# Processing Record 5 of Set 7 | yar-sale
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | nome
# Processing Record 8 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 7 | buchanan
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | prigen
# Processing Record 12 of Set 7 | lebyazhye
# Processing Record 13 of Set 7 | cairns
# Processing Record 14 of Set 7 | la romana
# Processing Record 15 of Set 7 | prince rupert
# Processing Record 16 of Set 7 | kamakhyanagar
# Processing Record 17 of Set 7 | lagoa
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | isangel
# Processing Record 20 of Set 7 | ostersund
# Processing Record 21 of Set 7 | faratsiho
# Processing Record 22 of Set 7 | tocopilla
# Processing Record 23 of Set 7 | meulaboh
# Processing Record 24 of Set 7 | serebryansk
# Processing Record 25 of Set 7 | ahipara
# Processing Record 26 of Set 7 | ostrovnoy
# Processing Record 27 of Set 7 | fort nelson
# Processing Record 28 of Set 7 | cockburn town
# Processing Record 29 of Set 7 | nabire
# Processing Record 30 of Set 7 | sakakah
# Processing Record 31 of Set 7 | hofn
# Processing Record 32 of Set 7 | gewane
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | muzhi
# Processing Record 35 of Set 7 | galesong
# Processing Record 36 of Set 7 | rawson
# Processing Record 37 of Set 7 | talnakh
# Processing Record 38 of Set 7 | qaqortoq
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | valdivia
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | umm lajj
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | norman wells
# Processing Record 45 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 46 of Set 7 | omboue
# Processing Record 47 of Set 7 | shimoda
# Processing Record 48 of Set 7 | geraldton
# Processing Record 49 of Set 7 | shadrinsk
# Processing Record 50 of Set 7 | mafinga
# Processing Record 1 of Set 8 | coutances
# Processing Record 2 of Set 8 | verkhnyaya toyma
# Processing Record 3 of Set 8 | azare
# Processing Record 4 of Set 8 | barranca
# Processing Record 5 of Set 8 | praia da vitoria
# Processing Record 6 of Set 8 | kyabe
# Processing Record 7 of Set 8 | sisimiut
# Processing Record 8 of Set 8 | rio brilhante
# Processing Record 9 of Set 8 | northam
# Processing Record 10 of Set 8 | tucurui
# Processing Record 11 of Set 8 | shumskiy
# Processing Record 12 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 8 | san vicente
# Processing Record 14 of Set 8 | severnyy
# Processing Record 15 of Set 8 | manicore
# Processing Record 16 of Set 8 | mulanje
# Processing Record 17 of Set 8 | kuala terengganu
# Processing Record 18 of Set 8 | shimonoseki
# Processing Record 19 of Set 8 | deep river
# Processing Record 20 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 8 | maneadero
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | dunda
# Processing Record 24 of Set 8 | saint anthony
# Processing Record 25 of Set 8 | spirit river
# Processing Record 26 of Set 8 | sioux lookout
# Processing Record 27 of Set 8 | aswan
# Processing Record 28 of Set 8 | grindavik
# Processing Record 29 of Set 8 | podyuga
# Processing Record 30 of Set 8 | miraflores
# Processing Record 31 of Set 8 | nikolskiy
# Processing Record 32 of Set 8 | manacapuru
# Processing Record 33 of Set 8 | bethel
# Processing Record 34 of Set 8 | george town
# Processing Record 35 of Set 8 | potiskum
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | xapuri
# Processing Record 38 of Set 8 | walvis bay
# Processing Record 39 of Set 8 | port augusta
# Processing Record 40 of Set 8 | vallenar
# Processing Record 41 of Set 8 | palia kalan
# Processing Record 42 of Set 8 | north bend
# Processing Record 43 of Set 8 | agadir
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | bud
# Processing Record 46 of Set 8 | seoul
# Processing Record 47 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 8 | nizhniy kuranakh
# Processing Record 49 of Set 8 | tlanchinol
# Processing Record 50 of Set 8 | sobolevo
# Processing Record 1 of Set 9 | aasiaat
# Processing Record 2 of Set 9 | khakurinokhabl
# Processing Record 3 of Set 9 | kaduna
# Processing Record 4 of Set 9 | revda
# Processing Record 5 of Set 9 | lebu
# Processing Record 6 of Set 9 | sao filipe
# Processing Record 7 of Set 9 | awjilah
# Processing Record 8 of Set 9 | poum
# Processing Record 9 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 10 of Set 9 | ouallam
# Processing Record 11 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 9 | weiser
# Processing Record 13 of Set 9 | gizo
# Processing Record 14 of Set 9 | tucuman
# Processing Record 15 of Set 9 | talcahuano
# Processing Record 16 of Set 9 | vila franca do campo
# Processing Record 17 of Set 9 | bichura
# Processing Record 18 of Set 9 | san quintin
# Processing Record 19 of Set 9 | tezu
# Processing Record 20 of Set 9 | san ramon
# Processing Record 21 of Set 9 | birobidzhan
# Processing Record 22 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 23 of Set 9 | pozega
# Processing Record 24 of Set 9 | mao
# Processing Record 25 of Set 9 | ambon
# Processing Record 26 of Set 9 | lompoc
# Processing Record 27 of Set 9 | ixhuatan
# Processing Record 28 of Set 9 | chalus
# Processing Record 29 of Set 9 | kavaratti
# Processing Record 30 of Set 9 | aquidauana
# Processing Record 31 of Set 9 | zemlyansk
# Processing Record 32 of Set 9 | hay river
# Processing Record 33 of Set 9 | oloron-sainte-marie
# Processing Record 34 of Set 9 | aksu
# Processing Record 35 of Set 9 | xixiang
# Processing Record 36 of Set 9 | uchaly
# Processing Record 37 of Set 9 | whitehorse
# Processing Record 38 of Set 9 | kodinsk
# Processing Record 39 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 40 of Set 9 | half moon bay
# Processing Record 41 of Set 9 | hamilton
# Processing Record 42 of Set 9 | bouar
# Processing Record 43 of Set 9 | balykshi
# Processing Record 44 of Set 9 | broome
# Processing Record 45 of Set 9 | little current
# Processing Record 46 of Set 9 | buin
# Processing Record 47 of Set 9 | quatre cocos
# Processing Record 48 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 9 | samarai
# Processing Record 50 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | nago
# Processing Record 3 of Set 10 | tessalit
# Processing Record 4 of Set 10 | ketchikan
# Processing Record 5 of Set 10 | tecuala
# Processing Record 6 of Set 10 | lanzhou
# Processing Record 7 of Set 10 | ambrolauri
# Processing Record 8 of Set 10 | colares
# Processing Record 9 of Set 10 | jaszbereny
# Processing Record 10 of Set 10 | kokomo
# Processing Record 11 of Set 10 | ust-shonosha
# Processing Record 12 of Set 10 | contamana
# Processing Record 13 of Set 10 | urengoy
# Processing Record 14 of Set 10 | genhe
# Processing Record 15 of Set 10 | bosaso
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | shimanovsk
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 10 | tarancon
# Processing Record 20 of Set 10 | sao joao da barra
# Processing Record 21 of Set 10 | mount isa
# Processing Record 22 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 23 of Set 10 | avera
# Processing Record 24 of Set 10 | dekar
# Processing Record 25 of Set 10 | bonfim
# Processing Record 26 of Set 10 | mangrol
# Processing Record 27 of Set 10 | ust-nera
# Processing Record 28 of Set 10 | north platte
# Processing Record 29 of Set 10 | sucre
# Processing Record 30 of Set 10 | mahibadhoo
# Processing Record 31 of Set 10 | raymond
# Processing Record 32 of Set 10 | tawang
# Processing Record 33 of Set 10 | burnie
# Processing Record 34 of Set 10 | baruun-urt
# Processing Record 35 of Set 10 | vostok
# Processing Record 36 of Set 10 | nantucket
# Processing Record 37 of Set 10 | sarangani
# Processing Record 38 of Set 10 | aksarka
# Processing Record 39 of Set 10 | shasta lake
# Processing Record 40 of Set 10 | acapulco
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | spearfish
# Processing Record 43 of Set 10 | susehri
# Processing Record 44 of Set 10 | moranbah
# Processing Record 45 of Set 10 | voi
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | popondetta
# Processing Record 48 of Set 10 | pinega
# Processing Record 49 of Set 10 | leningradskiy
# Processing Record 50 of Set 10 | florianopolis
# Processing Record 1 of Set 11 | olot
# Processing Record 2 of Set 11 | kashi
# Processing Record 3 of Set 11 | camacupa
# Processing Record 4 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 11 | bandar
# Processing Record 6 of Set 11 | alberdi
# Processing Record 7 of Set 11 | yelatma
# Processing Record 8 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 10 of Set 11 | vana-vigala
# Processing Record 11 of Set 11 | saint-francois
# Processing Record 12 of Set 11 | staryy nadym
# Processing Record 13 of Set 11 | balabac
# Processing Record 14 of Set 11 | siirt
# Processing Record 15 of Set 11 | shubarshi
# Processing Record 16 of Set 11 | shelburne
# Processing Record 17 of Set 11 | lysa nad labem
# Processing Record 18 of Set 11 | karratha
# Processing Record 19 of Set 11 | sandakan
# Processing Record 20 of Set 11 | pedro juan caballero
# Processing Record 21 of Set 11 | alta floresta
# Processing Record 22 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 11 | los llanos de aridane
# Processing Record 24 of Set 11 | shingu
# Processing Record 25 of Set 11 | serzhen-yurt
# Processing Record 26 of Set 11 | fort morgan
# Processing Record 27 of Set 11 | martapura
# Processing Record 28 of Set 11 | suluq
# Processing Record 29 of Set 11 | kedougou
# Processing Record 30 of Set 11 | delta del tigre
# Processing Record 31 of Set 11 | coffs harbour
# Processing Record 32 of Set 11 | san juan bautista
# Processing Record 33 of Set 11 | buraydah
# Processing Record 34 of Set 11 | victor harbor
# Processing Record 35 of Set 11 | hanstholm
# Processing Record 36 of Set 11 | ngunguru
# Processing Record 37 of Set 11 | hualmay
# Processing Record 38 of Set 11 | takaungu
# Processing Record 39 of Set 11 | abu zabad
# Processing Record 40 of Set 11 | havelock
# Processing Record 41 of Set 11 | termoli
# Processing Record 42 of Set 11 | bushehr
# Processing Record 43 of Set 11 | trelew
# Processing Record 44 of Set 11 | aleksandrov gay
# Processing Record 45 of Set 11 | iquique
# Processing Record 46 of Set 11 | bibai
# Processing Record 47 of Set 11 | mirnyy
# Processing Record 48 of Set 11 | askiz
# Processing Record 49 of Set 11 | mosquera
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | nalut
# Processing Record 2 of Set 12 | taunggyi
# Processing Record 3 of Set 12 | plettenberg bay
# Processing Record 4 of Set 12 | byron bay
# Processing Record 5 of Set 12 | kalmeshwar
# Processing Record 6 of Set 12 | gobabis
# Processing Record 7 of Set 12 | santana do livramento
# Processing Record 8 of Set 12 | colquiri
# Processing Record 9 of Set 12 | moroni
# Processing Record 10 of Set 12 | alyangula
# Processing Record 11 of Set 12 | matagami
# Processing Record 12 of Set 12 | bonavista
# Processing Record 13 of Set 12 | luvianos
# Processing Record 14 of Set 12 | fountain hills
# Processing Record 15 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 12 | taltal
# Processing Record 17 of Set 12 | quelimane
# Processing Record 18 of Set 12 | smithers
# Processing Record 19 of Set 12 | mormugao
# Processing Record 20 of Set 12 | whyalla
# Processing Record 21 of Set 12 | belaya gora
# Processing Record 22 of Set 12 | bafra
# Processing Record 23 of Set 12 | yatou
# Processing Record 24 of Set 12 | dolores
# Processing Record 25 of Set 12 | oktyabrskiy
# Processing Record 26 of Set 12 | qurayyat
# Processing Record 27 of Set 12 | dali
# Processing Record 28 of Set 12 | cerrito
# Processing Record 29 of Set 12 | horsham
# Processing Record 30 of Set 12 | bilibino
# Processing Record 31 of Set 12 | abashiri
# Processing Record 32 of Set 12 | nueva loja
# Processing Record 33 of Set 12 | yhu
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | kruisfontein
# Processing Record 36 of Set 12 | dvinskoy
# Processing Record 37 of Set 12 | safaga
# Processing Record 38 of Set 12 | kobojango
# City not found. Skipping...
# Processing Record 39 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 40 of Set 12 | eichenzell
# Processing Record 41 of Set 12 | zelenets
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 548

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Magadi  12.9667   77.2333     75.54        86         100        7.25
# 1     Hare Bay  48.8499  -54.0148     51.19        59          97       14.88
# 2   Villarrica -25.7500  -56.4333     67.62        92         100        6.69
# 3    Busselton -33.6500  115.3333     48.09        74           0        7.99
# 4       Albany  42.6001  -73.9662     92.44        41          57        1.01
# 5     Kalmunai   7.4167   81.8167     82.15        74         100        3.49
# 6  Port Alfred -33.5906   26.8910     65.43        37           0        8.88
# 7    Jamestown  42.0970  -79.2353     85.32        50           1        9.22
# 8      Ushuaia -54.8000  -68.3000     38.86        81          75        0.00
# 9   Nikolskoye  59.7035   30.7861     67.89        71          55        5.17
#
#   Country                 Date
# 0      IN  2021-06-06 19:25:17
# 1      CA  2021-06-06 19:25:17
# 2      PY  2021-06-06 19:25:17
# 3      AU  2021-06-06 19:18:03
# 4      US  2021-06-06 19:21:09
# 5      LK  2021-06-06 19:24:07
# 6      ZA  2021-06-06 19:18:04
# 7      US  2021-06-06 19:22:34
# 8      AR  2021-06-06 19:20:28
# 9      RU  2021-06-06 19:20:53

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Magadi      IN  2021-06-06 19:25:17  12.9667   77.2333     75.54
# 1     Hare Bay      CA  2021-06-06 19:25:17  48.8499  -54.0148     51.19
# 2   Villarrica      PY  2021-06-06 19:25:17 -25.7500  -56.4333     67.62
# 3    Busselton      AU  2021-06-06 19:18:03 -33.6500  115.3333     48.09
# 4       Albany      US  2021-06-06 19:21:09  42.6001  -73.9662     92.44
# 5     Kalmunai      LK  2021-06-06 19:24:07   7.4167   81.8167     82.15
# 6  Port Alfred      ZA  2021-06-06 19:18:04 -33.5906   26.8910     65.43
# 7    Jamestown      US  2021-06-06 19:22:34  42.0970  -79.2353     85.32
# 8      Ushuaia      AR  2021-06-06 19:20:28 -54.8000  -68.3000     38.86
# 9   Nikolskoye      RU  2021-06-06 19:20:53  59.7035   30.7861     67.89
#
#    Humidity  Cloudiness  Wind Speed
# 0        86         100        7.25
# 1        59          97       14.88
# 2        92         100        6.69
# 3        74           0        7.99
# 4        41          57        1.01
# 5        74         100        3.49
# 6        37           0        8.88
# 7        50           1        9.22
# 8        81          75        0.00
# 9        71          55        5.17

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
   
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                     Berlevag
# Country                        NO
# Date          2021-06-06 19:24:15
# Lat                       70.8578
# Lng                       29.0864
# Max Temp                    40.95
# Humidity                       65
# Cloudiness                     40
# Wind Speed                   6.91
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 543    False
# 544     True
# 545     True
# 546     True
# 547     True
# Name: Lat, Length: 548, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#         City Country                 Date      Lat      Lng  Max Temp  \
# 0     Magadi      IN  2021-06-06 19:25:17  12.9667  77.2333     75.54
# 1   Hare Bay      CA  2021-06-06 19:25:17  48.8499 -54.0148     51.19
# 4     Albany      US  2021-06-06 19:21:09  42.6001 -73.9662     92.44
# 5   Kalmunai      LK  2021-06-06 19:24:07   7.4167  81.8167     82.15
# 7  Jamestown      US  2021-06-06 19:22:34  42.0970 -79.2353     85.32
#
#    Humidity  Cloudiness  Wind Speed
# 0        86         100        7.25
# 1        59          97       14.88
# 4        41          57        1.01
# 5        74         100        3.49
# 7        50           1        9.22

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_value, y_value,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
linregress(x_value,y_value)
# Out:
# LinregressResult(slope=-0.6700669749469356, intercept=94.30104678803696, rvalue=-0.750442359418148, pvalue=5.7139845830070254e-70, stderr=0.030353887228040992)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
linregress(x_values,y_values)
# Out:
# LinregressResult(slope=0.707332275895346, intercept=81.01095670550177, rvalue=0.6879761206088448, pvalue=6.915448493004718e-25, stderr=0.05791260926071204)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
title='Linear Regression on the Northern Hemisphere \n for % Humidity'
# Call the function.
plot_linear_regression(x_values, y_values, title,'% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
title='Linear Regression on the Southern Hemisphere \n for % Humidity'
# Call the function.
plot_linear_regression(x_values, y_values, title, '% Humidity',(-55,30))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
title='Linear Regression on the Northern Hemisphere \n for % Cloudiness'
# Call the function.
plot_linear_regression(x_values, y_values,
                       title, '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
title = 'Linear Regression on the Southern Hemisphere \n for % Cloudiness'
# Call the function.
plot_linear_regression(x_values, y_values,
                       title, '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
title = 'Linear Regression on the Northern Hemisphere \n for Wind Speed'
# Call the function.
plot_linear_regression(x_values, y_values,
                       title, 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
title = 'Linear Regression on the Southern Hemisphere \n for Wind Speed'
# Call the function.
plot_linear_regression(x_values, y_values,
                       title, 'Wind Speed',(-50,35))
